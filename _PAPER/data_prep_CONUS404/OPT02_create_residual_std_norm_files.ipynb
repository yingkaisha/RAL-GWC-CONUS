# %% [markdown]
# # Create resaidual norm files for CREDIT

# %%
import os
import yaml
import copy
import numpy as np
import xarray as xr

# %%
from scipy.stats import gmean

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## ERA5 (x)

# %%
# # get variable information from data_preprocessing/config
# config_name = os.path.realpath('data_config_ERA5.yml')

# with open(config_name, 'r') as stream:
#     conf = yaml.safe_load(stream)

# %%
# ds_std = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/ERA5_6h_std_1980_2019.nc')
# ds_residual = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/ERA5_6h_residual_1980_2019.nc')

# ds_residual_norm = ds_std * ds_residual

# %%
# ds_residual_norm.to_netcdf(
#     '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/ERA5_6h_std_residual_1980_2019.nc'
# )

# %% [markdown]
# ## WRF

# %%
# get variable information from data_preprocessing/config
config_name = os.path.realpath('data_config_WRF.yml')

with open(config_name, 'r') as stream:
    conf = yaml.safe_load(stream)

# %%
# # =========================================== #
# # No Soil var version
# ds_std = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_1980_2019_12lev.nc')
# ds_residual = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_residual_1980_2019_12lev_clean.nc')
# ds_residual_norm = ds_std * ds_residual
# ds_residual_norm.to_netcdf(
#     '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_12lev_clean.nc'
# )

# %%
# # =========================================== #
# # Soil var version
# ds_std = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_1980_2019_12lev.nc')
# ds_residual = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_residual_1980_2019_12lev.nc')
# ds_residual_norm = ds_std * ds_residual

# ds_residual_norm.to_netcdf(
#     '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_12lev.nc'
# )

# %%
ds_new = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_12lev.nc')
ds_W = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_12lev_clean.nc')
ds_old = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_15lev_20250629.nc')

for varname in ds_W.keys():
    print(f'=================== {varname} ===================')
    try:
        print(ds_W[varname].values)
        print(ds_new[varname].values)
        print(ds_old[varname].values)
    except:
        pass
# Out:
# =================== WRF_T2 ===================
# 8.094474120008009
# 8.23549272528566
# 10.189354784303438
# =================== WRF_U10 ===================
# 6.142079400422017
# 6.249084186367426
# 7.731672891456442
# =================== WRF_TD2 ===================
# 6.369450400355944
# 6.480416350524734
# 8.01788837026834
# =================== WRF_MSLP ===================
# 371.85083034637614
# 378.3290628651714
# 532.0745177121177
# =================== WRF_V10 ===================
# 6.997238822624253
# 7.119141844974039
# 8.808150822051132
# =================== WRF_SP ===================
# 367.64814098789464
# 374.05315597792134
# 462.7968770763778
# =================== WRF_PWAT_05 ===================
# 0.031497218478654235
# 0.032045950089149636
# 0.03964881832217268
# =================== WRF_U ===================
# [ 7.48512051 11.62890336 11.54120025 10.80402855 10.47789735 10.36729277
#  10.66877269 11.21919854 11.92466183 12.82737692  9.84116841  8.72321314]
# ...

# %%
ds_new = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_12lev.nc')
ds_W = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_12lev_clean.nc')
ds_old = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/mean_std/C404_std_residual_1980_2019_15lev_20250629.nc')

for varname in ds_W.keys():
    print(f'=================== {varname} ===================')
    try:
        print(ds_W[varname].values)
        print(ds_new[varname].values)
        print(ds_old[varname].values)
    except:
        pass
# Out:
# =================== WRF_T2 ===================
# 8.094474120008009
# 12.073910238761993
# 10.189354784303438
# =================== WRF_U10 ===================
# 6.142079400422017
# 9.161671809752
# 7.731672891456442
# =================== WRF_TD2 ===================
# 6.369450400355944
# 9.500823804483076
# 8.01788837026834
# =================== WRF_MSLP ===================
# 371.85083034637614
# 554.6615482670561
# 532.0745177121177
# =================== WRF_V10 ===================
# 6.997238822624253
# 10.437247955950259
# 8.808150822051132
# =================== WRF_SP ===================
# 367.64814098789464
# 548.3927167996383
# 462.7968770763778
# =================== WRF_PWAT_05 ===================
# 0.031497218478654235
# 0.046982000688831724
# 0.03964881832217268
# =================== WRF_U ===================
# [ 7.48512051 11.62890336 11.54120025 10.80402855 10.47789735 10.36729277
#  10.66877269 11.21919854 11.92466183 12.82737692  9.84116841  8.72321314]
# ...
