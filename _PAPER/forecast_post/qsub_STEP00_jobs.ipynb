# %% [markdown]
# # Generate qsub scripts for STEP00 operations

# %%
import os
import yaml
import numpy as np

# %%
conf = {
    'qsub': {
        'qsub_loc': '/glade/u/home/ksha/CONUS-404-prep/qsub/',
        'scripts_loc': '/glade/u/home/ksha/CONUS-404-prep/opt_ERA5/scripts/'
    }
}

# %% [markdown]
# ## Dscale baseline

# %%
IND_max = 46000
INDs = np.arange(0, IND_max+1000, 1000)
INDs[-1] = IND_max

# %%
for i, ind_start in enumerate(INDs[:-1]):
    
    ind_end = INDs[i+1]
    
    f = open('{}gather_prog_dscale_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N gather_prog
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=128GB
#PBS -q casper
#PBS -o gather_prog.log
#PBS -e gather_prog.err

conda activate credit
cd {}
python gather_prog_dscale_base.py {} {}
'''.format(conf['qsub']['scripts_loc'], ind_start, ind_end, ind_start, ind_end)
    
    print(heads, file=f)    
    f.close()

f = open('{}step00_gather_prog_dscale_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, ind_start in enumerate(INDs[:-1]):
    print('qsub gather_prog_dscale_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
years = np.arange(2020, 2025)

# %%
for i_year, year in enumerate(years):
    
    f = open('{}diag_dscale_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}_dscale
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=256GB
#PBS -q casper
#PBS -o {}.log
#PBS -e {}.err

conda activate credit
cd {}
python merge_diag_dscale_base.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)
    f.close()

f = open('{}batch_diag_dscale.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub diag_dscale_{}.sh'.format(year), file=f)
f.close()

# %% [markdown]
# ## B3H

# %%
IND_max = 46000
INDs = np.arange(0, IND_max+1000, 1000)
INDs[-1] = IND_max

# %%
for i, ind_start in enumerate(INDs[:-1]):
    
    ind_end = INDs[i+1]
    
    f = open('{}gather_prog_B3H_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N gather_prog
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=128GB
#PBS -q casper
#PBS -o gather_prog.log
#PBS -e gather_prog.err

conda activate credit
cd {}
python gather_prog_B3H.py {} {}
'''.format(conf['qsub']['scripts_loc'], ind_start, ind_end, ind_start, ind_end)
    
    print(heads, file=f)    
    f.close()

f = open('{}step00_gather_prog_B3H_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, ind_start in enumerate(INDs[:-1]):
    print('qsub gather_prog_B3H_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
IND_max = 20000
INDs = np.arange(0, IND_max+1000, 1000)
INDs[-1] = IND_max

# %%
for i, ind_start in enumerate(INDs[:-1]):
    
    ind_end = INDs[i+1]
    
    f = open('{}gather_prog_B3H_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N gather_prog
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=128GB
#PBS -q casper
#PBS -o gather_prog.log
#PBS -e gather_prog.err

conda activate credit
cd {}
python gather_prog_B3H_p2.py {} {}
'''.format(conf['qsub']['scripts_loc'], ind_start, ind_end, ind_start, ind_end)
    
    print(heads, file=f)    
    f.close()

f = open('{}step00_gather_prog_B3H_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, ind_start in enumerate(INDs[:-1]):
    print('qsub gather_prog_B3H_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
years = np.arange(2020, 2025)

# %%
for i_year, year in enumerate(years):
    
    f = open('{}diag_B3H_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}_B3H
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=256GB
#PBS -q casper
#PBS -o {}.log
#PBS -e {}.err

conda activate credit
cd {}
python merge_diag_B3H.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_diag_B3H.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub diag_B3H_{}.sh'.format(year), file=f)
f.close()

# %% [markdown]
# ## B6H

# %%
IND_max = 46000
INDs = np.arange(0, IND_max+1000, 1000)
INDs[-1] = IND_max

# %%
for i, ind_start in enumerate(INDs[:-1]):
    
    ind_end = INDs[i+1]
    
    f = open('{}gather_prog_B6H_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N gather_prog
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=128GB
#PBS -q casper
#PBS -o gather_prog.log
#PBS -e gather_prog.err

conda activate credit
cd {}
python gather_prog_B6H.py {} {}
'''.format(conf['qsub']['scripts_loc'], ind_start, ind_end, ind_start, ind_end)
    
    print(heads, file=f)    
    f.close()

f = open('{}step00_gather_prog_B6H_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, ind_start in enumerate(INDs[:-1]):
    print('qsub gather_prog_B6H_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
IND_max = 20000
INDs = np.arange(0, IND_max+1000, 1000)
INDs[-1] = IND_max

# %%
for i, ind_start in enumerate(INDs[:-1]):
    
    ind_end = INDs[i+1]
    
    f = open('{}gather_prog_B6H_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N gather_prog
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=128GB
#PBS -q casper
#PBS -o gather_prog.log
#PBS -e gather_prog.err

conda activate credit
cd {}
python gather_prog_B6H_p2.py {} {}
'''.format(conf['qsub']['scripts_loc'], ind_start, ind_end, ind_start, ind_end)
    
    print(heads, file=f)    
    f.close()

f = open('{}step00_gather_prog_B6H_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, ind_start in enumerate(INDs[:-1]):
    print('qsub gather_prog_B6H_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
years = np.arange(2020, 2025)

# %%
for i_year, year in enumerate(years):
    
    f = open('{}diag_B6H_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}_B6H
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=256GB
#PBS -q casper
#PBS -o {}.log
#PBS -e {}.err

conda activate credit
cd {}
python merge_diag_B6H.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_diag_B6H.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub diag_B6H_{}.sh'.format(year), file=f)
f.close()

# %% [markdown]
# ## GDAS

# %%
IND_max = 46000
INDs = np.arange(0, IND_max+1000, 1000)
INDs[-1] = IND_max

# %%
for i, ind_start in enumerate(INDs[:-1]):
    
    ind_end = INDs[i+1]
    
    f = open('{}gather_prog_GDAS_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N gather_prog
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=128GB
#PBS -q casper
#PBS -o gather_prog.log
#PBS -e gather_prog.err

conda activate credit
cd {}
python gather_prog_GDAS.py {} {}
'''.format(conf['qsub']['scripts_loc'], ind_start, ind_end, ind_start, ind_end)
    
    print(heads, file=f)    
    f.close()

f = open('{}step00_gather_prog_GDAS_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, ind_start in enumerate(INDs[:-1]):
    print('qsub gather_prog_GDAS_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
IND_max = 20000
INDs = np.arange(0, IND_max+1000, 1000)
INDs[-1] = IND_max

# %%
for i, ind_start in enumerate(INDs[:-1]):
    
    ind_end = INDs[i+1]
    
    f = open('{}gather_prog_GDAS_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N gather_prog
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=128GB
#PBS -q casper
#PBS -o gather_prog.log
#PBS -e gather_prog.err

conda activate credit
cd {}
python gather_prog_GDAS_p2.py {} {}
'''.format(conf['qsub']['scripts_loc'], ind_start, ind_end, ind_start, ind_end)
    
    print(heads, file=f)    
    f.close()

f = open('{}step00_gather_prog_GDAS_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, ind_start in enumerate(INDs[:-1]):
    print('qsub gather_prog_GDAS_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
years = np.arange(2020, 2025)

# %%
for i_year, year in enumerate(years):
    
    f = open('{}diag_GDAS_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}_GDAS
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=16:mem=304GB
#PBS -q casper
#PBS -o {}.log
#PBS -e {}.err

conda activate credit
cd {}
python merge_diag_GDAS.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_diag_GDAS.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub diag_GDAS_{}.sh'.format(year), file=f)
f.close()

# %% [markdown]
# ## CESM-ENS

# %%
IND_max = 27000
INDs = np.arange(0, IND_max+180, 180)
INDs[-1] = IND_max

# %%
for i, ind_start in enumerate(INDs[:-1]):
    
    ind_end = INDs[i+1]
    
    f = open('{}gather_prog_CESM_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N gather_prog
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=16:mem=256GB
#PBS -q casper
#PBS -o gather_prog.log
#PBS -e gather_prog.err

conda activate credit
cd {}
python gather_prog_CESM.py {} {}
'''.format(conf['qsub']['scripts_loc'], ind_start, ind_end, ind_start, ind_end)
    
    print(heads, file=f)    
    f.close()

f = open('{}step00_gather_prog_CESM_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, ind_start in enumerate(INDs[:-1]):
    print('qsub gather_prog_CESM_{:03d}.sh'.format(i), file=f)
    
f.close()

# %% [markdown]
# ## CESM-SSP

# %% [markdown]
# ```
# rm -r /glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/opt_init_ERA5/prog_outputs/CESM_SSP/*.zarr
# rm -r /glade/derecho/scratch/ksha/DWC_data/CONUS_domain_GP/opt_init_ERA5/prog_outputs/CESM_HIST/*.zarr
# ```

# %%
IND_max = 46000
INDs = np.arange(0, IND_max+500, 500)
INDs[-1] = IND_max

# %%
for i, ind_start in enumerate(INDs[:-1]):
    
    ind_end = INDs[i+1]
    
    f = open('{}gather_prog_SSP_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N gather_prog
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=16:mem=256GB
#PBS -q casper
#PBS -o gather_prog.log
#PBS -e gather_prog.err

conda activate credit
cd {}
python gather_prog_CESM_SSP.py {} {}
'''.format(conf['qsub']['scripts_loc'], ind_start, ind_end, ind_start, ind_end)
    
    print(heads, file=f)    
    f.close()

f = open('{}step00_gather_prog_SSP_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, ind_start in enumerate(INDs[:-1]):
    print('qsub gather_prog_SSP_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
# years = np.arange(2070, 2075)

# %%
# for i_year, year in enumerate(years):
    
#     f = open('{}diag_SSP_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
#     heads = '''#!/bin/bash -l

# #PBS -N {}_SSP
# #PBS -A P48500028
# #PBS -l walltime=23:59:59
# #PBS -l select=1:ncpus=16:mem=256GB
# #PBS -q casper
# #PBS -o {}.log
# #PBS -e {}.err

# conda activate credit
# cd {}
# python merge_diag_CESM_SSP.py {}
# '''.format(year, year, year, 
#            conf['qsub']['scripts_loc'], 
#            year)
    
#     print(heads, file=f)    
#     f.close()

# f = open('{}batch_diag_SSP.sh'.format(conf['qsub']['qsub_loc']), 'w')
# for i_year, year in enumerate(years):
#     print('qsub diag_SSP_{}.sh'.format(year), file=f)
# f.close()

# %% [markdown]
# ## CESM-HIST

# %%
IND_max = 46000
INDs = np.arange(0, IND_max+500, 500)
INDs[-1] = IND_max

# %%
for i, ind_start in enumerate(INDs[:-1]):
    
    ind_end = INDs[i+1]
    
    f = open('{}gather_prog_HIST_{:03d}.sh'.format(conf['qsub']['qsub_loc'], i), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N gather_hist
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=16:mem=256GB
#PBS -q casper
#PBS -o gather_prog.log
#PBS -e gather_prog.err

conda activate credit
cd {}
python gather_prog_CESM_HIST.py {} {}
'''.format(conf['qsub']['scripts_loc'], ind_start, ind_end, ind_start, ind_end)
    
    print(heads, file=f)    
    f.close()

f = open('{}step00_gather_prog_HIST_all.sh'.format(conf['qsub']['qsub_loc']), 'w')

for i, ind_start in enumerate(INDs[:-1]):
    print('qsub gather_prog_HIST_{:03d}.sh'.format(i), file=f)
    
f.close()

# %%
# years = np.arange(1980, 1985)

# %%
# for i_year, year in enumerate(years):
    
#     f = open('{}diag_HIST_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
#     heads = '''#!/bin/bash -l

# #PBS -N {}_HIST
# #PBS -A P48500028
# #PBS -l walltime=23:59:59
# #PBS -l select=1:ncpus=16:mem=256GB
# #PBS -q casper
# #PBS -o {}.log
# #PBS -e {}.err

# conda activate credit
# cd {}
# python merge_diag_CESM_HIST.py {}
# '''.format(year, year, year, 
#            conf['qsub']['scripts_loc'], 
#            year)
    
#     print(heads, file=f)    
#     f.close()

# f = open('{}batch_diag_HIST.sh'.format(conf['qsub']['qsub_loc']), 'w')
# for i_year, year in enumerate(years):
#     print('qsub diag_HIST_{}.sh'.format(year), file=f)
# f.close()
